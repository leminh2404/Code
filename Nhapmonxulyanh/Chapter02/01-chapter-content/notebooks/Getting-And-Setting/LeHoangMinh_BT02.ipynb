# %%
import cv2

# %%
rgb_img = cv2.imread('cat2.jpg', cv2.IMREAD_COLOR)

# %%
dimensions = rgb_img.shape

# %%
print(dimensions)
# Out:
# (1440, 1440, 3)

# %%
cv2.startWindowThread()
cv2.imshow("RGB Image", rgb_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(rgb_img, cmap='gray')

# %%
print("Pixel at (6,40) - Intensity: {}".format(i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 print("Pixel at (6,40) - Intensity: {}".format(i))
#
# NameError: name 'i' is not defined

# %%
i = rgb_img[1, 1]

# %%
x, y = 120, 120
rgb_img[y, x] = (0, 0, 255)

# %%
cv2.imshow('Modified Image', rgb_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
height, width, channels = rgb_img.shape
smaller_image = cv2.resize(rgb_img, (width // 2, height // 2))

# %%
print(f"Kích thước ảnh: {width}x{height}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 print(f"Kích thước ảnh: {width}x{height}")
#
# NameError: name 'width' is not defined

# %%
cv2.imshow('Smaller Image', smaller_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 cv2.imshow('Smaller Image', smaller_image)
#       2 cv2.waitKey(0)
#       3 cv2.destroyAllWindows()
#
# NameError: name 'smaller_image' is not defined

# %%
b, g, r = cv2.split(rgb_img)

# %%
print(b)
# Out:
# [[161 161 161 ... 200 200 200]
#  [161 161 161 ... 200 200 200]
#  [161 161 161 ... 200 200 200]
#  ...
#  [ 33  33  33 ... 134 134 134]
#  [ 33  33  33 ... 134 134 134]
#  [ 33  33  33 ... 134 134 134]]

# %%
print(g)
# Out:
# [[183 183 183 ... 208 208 208]
#  [183 183 183 ... 208 208 208]
#  [183 183 183 ... 208 208 208]
#  ...
#  [ 58  58  58 ... 132 132 132]
#  [ 58  58  58 ... 132 132 132]
#  [ 58  58  58 ... 132 132 132]]

# %%
print(r)
# Out:
# [[198 198 198 ... 232 232 232]
#  [198 198 198 ... 232 232 232]
#  [198 198 198 ... 232 232 232]
#  ...
#  [ 91  91  91 ... 137 137 137]
#  [ 91  91  91 ... 137 137 137]
#  [ 91  91  91 ... 137 137 137]]

# %%
(b, g, r) = rgb_img[120, 120]

# %%
print("Pixel at (120, 120) - Red: {}, Green: {}, Blue: {}".format(r, g, b))
# Out:
# Pixel at (120, 120) - Red: 255, Green: 0, Blue: 0

# %%
top_left_corner = rgb_img[0:100, 0:100]

# %%
plt.imshow(top_left_corner,cmap='gray')

# %%
rgb_img[0:100, 0:100] = top_left_corner

# %%
plt.imshow(rgb_img, cmap='gray')

# %%
rgb_img[0:50, 0:50] = 255

# %%
plt.imshow(rgb_img, cmap='gray')

# %%
plt.imshow(top_left_corner,cmap='gray')
